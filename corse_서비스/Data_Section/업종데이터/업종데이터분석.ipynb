# %% [markdown]
# # 필요한 패키지 임포트

# %%
import pandas as pd

# %%
data_2019 = pd.read_csv("../data/2019_data.csv" , encoding='euc-kr')
data_2020 = pd.read_csv("../data/2020_data.csv" , encoding='utf-8')
data_2021 = pd.read_csv("../data/2021_data.csv" , encoding='utf-8')

# %%
road = pd.read_excel('../data/road_2021.xlsx')
road_del = pd.read_excel('../data/road_del.xlsx')
market = pd.read_excel('../data/market.xlsx')
travel_special = pd.read_excel('../data/travel_special.xlsx')
dev = pd.read_excel('../data/dev.xlsx')

# %%
road_pre = pd.concat([road,road_del], axis = 0)

# %%
data_2019['상권_구분_코드_명'].unique()
# Out:
# array(['골목상권', '전통시장', '발달상권', '관광특구'], dtype=object)

# %%
data_road_2019 = data_2019[data_2019['상권_구분_코드_명'] == '골목상권']
data_tran_2019 = data_2019[data_2019['상권_구분_코드_명'] == '전통시장']
data_trav_2019 = data_2019[data_2019['상권_구분_코드_명'] == '관광특구']
data_dev_2019 = data_2019[data_2019['상권_구분_코드_명'] == '발달상권']

data_road_2020 = data_2020[data_2020['상권_구분_코드_명'] == '골목상권']
data_tran_2020 = data_2020[data_2020['상권_구분_코드_명'] == '전통시장']
data_trav_2020 = data_2020[data_2020['상권_구분_코드_명'] == '관광특구']
data_dev_2020 = data_2020[data_2020['상권_구분_코드_명'] == '발달상권']

data_road_2021 = data_2021[data_2021['상권_구분_코드_명'] == '골목상권']
data_tran_2021 = data_2021[data_2021['상권_구분_코드_명'] == '전통시장']
data_trav_2021 = data_2021[data_2021['상권_구분_코드_명'] == '관광특구']
data_dev_2021 = data_2021[data_2021['상권_구분_코드_명'] == '발달상권']

# %% [markdown]
# # 골목상권 를 확인하여 시군구 등록

# %%
data_road_2019_df = data_road_2019.join(road_pre.set_index('도로명')['시군구'], on='상권_코드_명')
data_road_2020_df = data_road_2020.join(road_pre.set_index('도로명')['시군구'], on='상권_코드_명')
data_road_2021_df = data_road_2021.join(road_pre.set_index('도로명')['시군구'], on='상권_코드_명')

# %%
data_road_2019_df=data_road_2019_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)
data_road_2020_df=data_road_2020_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)
data_road_2021_df=data_road_2021_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)

# %% [markdown]
# # 관광특구 를 확인해서 시군구 등록

# %%
data_travel_2019_df = data_trav_2019.join(travel_special.set_index('상권_코드_명')['시군구'], on='상권_코드_명')
data_travel_2020_df = data_trav_2020.join(travel_special.set_index('상권_코드_명')['시군구'], on='상권_코드_명')
data_travel_2021_df= data_trav_2021.join(travel_special.set_index('상권_코드_명')['시군구'], on='상권_코드_명')

# %%
data_travel_2019_df=data_travel_2019_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)
data_travel_2020_df=data_travel_2020_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)
data_travel_2021_df=data_travel_2021_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)

# %% [markdown]
# # 전통시장 을 확인해서 시군구 등록

# %%
data_market_2019_df = data_tran_2019.join(market.set_index('시장명')['시군구'], on='상권_코드_명')
data_market_2020_df = data_tran_2020.join(market.set_index('시장명')['시군구'], on='상권_코드_명')
data_market_2021_df = data_tran_2021.join(market.set_index('시장명')['시군구'], on='상권_코드_명')

# %%
data_market_2019_df=data_market_2019_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)
data_market_2020_df=data_market_2020_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)
data_market_2021_df=data_market_2021_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)

# %% [markdown]
# # 발달상권 을 확인해서 시군구 등록

# %%
data_dev_2019_df = data_dev_2019.join(dev.set_index('상권명')['시군구'], on='상권_코드_명')
data_dev_2020_df = data_dev_2020.join(dev.set_index('상권명')['시군구'], on='상권_코드_명')
data_dev_2021_df = data_dev_2021.join(dev.set_index('상권명')['시군구'], on='상권_코드_명')

# %%
data_dev_2019_df=data_dev_2019_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)
data_dev_2020_df=data_dev_2020_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)
data_dev_2021_df=data_dev_2021_df.drop(['상권_구분_코드','상권_구분_코드_명','상권_코드_명','상권_코드'], axis = 1)

# %%
result_2019 = pd.concat([data_road_2019_df,data_market_2019_df,data_travel_2019_df,data_dev_2019_df])
result_2020 = pd.concat([data_road_2020_df,data_market_2020_df,data_travel_2020_df,data_dev_2020_df])
result_2021 = pd.concat([data_road_2021_df,data_market_2021_df,data_travel_2021_df,data_dev_2021_df])

# %%
result = pd .concat([result_2019,result_2020,result_2021])

# %%
len(result.서비스_업종_코드_명.unique())
# Out:
# 63

# %%
result.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '서비스_업종_코드', '서비스_업종_코드_명', '분기당_매출_금액',
#        '분기당_매출_건수', '주중_매출_비율', '주말_매출_비율', '월요일_매출_비율', '화요일_매출_비율',
#        '수요일_매출_비율', '목요일_매출_비율', '금요일_매출_비율', '토요일_매출_비율', '일요일_매출_비율',
#        '시간대_00~06_매출_비율', '시간대_06~11_매출_비율', '시간대_11~14_매출_비율',
#        '시간대_14~17_매출_비율', '시간대_17~21_매출_비율', '시간대_21~24_매출_비율', '남성_매출_비율',
#        '여성_매출_비율', '연령대_10_매출_비율', '연령대_20_매출_비율', '연령대_30_매출_비율',
#        '연령대_40_매출_비율', '연령대_50_매출_비율', '연령대_60_이상_매출_비율', '주중_매출_금액',
#        '주말_매출_금액', '월요일_매출_금액', '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액',
#        '금요일_매출_금액', '토요일_매출_금액', '일요일_매출_금액', '시간대_00~06_매출_금액',
#        '시간대_06~11_매출_금액', '시간대_11~14_매출_금액', '시간대_14~17_매출_금액',
#        '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액', '여성_매출_금액',
#        '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액', '연령대_40_매출_금액',
#        '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수', '주말_매출_건수', '월요일_매출_건수',
# ...

# %%
result['연도별분기'] = result['기준_년_코드'].apply(str) + "-" + result['기준_분기_코드'].apply(str)

# %%
result=result.drop(['기준_년_코드','기준_분기_코드'], axis=1)

# %% [markdown]
# 매출 형태가 10의 거듭제곱으로 표현되있으므로 int형으로 변경

# %%
def ten_minus(x):
    a=int(x)
    return a

# %% [markdown]
# 함수적용

# %%
result['분기당_매출_금액']=result['분기당_매출_금액'].apply(ten_minus)

# %%
result
# Out:
#       서비스_업종_코드 서비스_업종_코드_명   분기당_매출_금액  분기당_매출_건수  주중_매출_비율  주말_매출_비율  \
# 0      CS200003        예술학원    20061598        125       100         0
# 1      CS200037         노래방      510636         21       100         0
# 3      CS300017      시계및귀금속     5085873         10        50        50
# 4      CS200001      일반교습학원      527027         53       100         0
# 5      CS200005      스포츠 강습    22390312        168       100         0
# ...         ...         ...         ...        ...       ...       ...
# 44033  CS100006      패스트푸드점   196562293      16515        72        28
# 44034  CS100005         제과점  1659143544     195540        67        33
# 44035  CS100003       일식음식점   387388456       5821        68        32
# 44036  CS100002       중식음식점   112368498       4671        65        35
# 44037  CS100001       한식음식점  2907921088      74719        70        30
#
#        월요일_매출_비율  화요일_매출_비율  수요일_매출_비율  목요일_매출_비율  ...  여성_매출_건수  \
# ...

# %%
result.columns
# Out:
# Index(['서비스_업종_코드', '서비스_업종_코드_명', '분기당_매출_금액', '분기당_매출_건수', '주중_매출_비율',
#        '주말_매출_비율', '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율',
#        '금요일_매출_비율', '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율',
#        '시간대_06~11_매출_비율', '시간대_11~14_매출_비율', '시간대_14~17_매출_비율',
#        '시간대_17~21_매출_비율', '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율',
#        '연령대_10_매출_비율', '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율',
#        '연령대_50_매출_비율', '연령대_60_이상_매출_비율', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액',
#        '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액',
#        '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
#        '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
#        '주말_매출_건수', '월요일_매출_건수', '화요일_매출_건수', '수요일_매출_건수', '목요일_매출_건수',
# ...

# %%
result = result.drop(['서비스_업종_코드','주중_매출_비율','주말_매출_비율', '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율',
       '금요일_매출_비율', '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율',
       '시간대_06~11_매출_비율', '시간대_11~14_매출_비율', '시간대_14~17_매출_비율',
       '시간대_17~21_매출_비율', '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율',
       '연령대_10_매출_비율', '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율',
       '연령대_50_매출_비율', '연령대_60_이상_매출_비율','시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
       '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
       '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
       '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
       '주말_매출_건수', '월요일_매출_건수', '화요일_매출_건수', '수요일_매출_건수', '목요일_매출_건수',
       '금요일_매출_건수', '토요일_매출_건수', '일요일_매출_건수', '시간대_건수~06_매출_건수',
       '시간대_건수~11_매출_건수', '시간대_건수~14_매출_건수', '시간대_건수~17_매출_건수',
       '시간대_건수~21_매출_건수', '시간대_건수~24_매출_건수', '남성_매출_건수', '여성_매출_건수',
       '연령대_10_매출_건수', '연령대_20_매출_건수', '연령대_30_매출_건수', '연령대_40_매출_건수',
       '연령대_50_매출_건수', '연령대_60_이상_매출_건수'], axis =1 )

# %%
result = result.reset_index()

# %%
result = result.drop(['pri_key'], axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/p7/569lvwkj0q98gy0g8l5r64b80000gn/T/ipykernel_26965/845716136.py in <module>
# ----> 1 result = result.drop(['pri_key'], axis =1)
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
result = result.set_index('index')

# %%
result = result.drop(['index'], axis = 1)

# %%
result.dtypes
# Out:
# 서비스_업종_코드_명     object
# 분기당_매출_금액        int64
# 분기당_매출_건수        int64
# 주중_매출_금액       float64
# 주말_매출_금액       float64
# 월요일_매출_금액        int64
# 화요일_매출_금액      float64
# 수요일_매출_금액        int64
# 목요일_매출_금액        int64
# 금요일_매출_금액        int64
# 토요일_매출_금액        int64
# 일요일_매출_금액        int64
# 점포수              int64
# 시군구             object
# 연도별분기           object
# dtype: object

# %%
result = result.astype({'주중_매출_금액': 'int', '주말_매출_금액': 'int', '화요일_매출_금액': 'int'})

# %%
result.dtypes
# Out:
# 서비스_업종_코드_명    object
# 분기당_매출_금액       int64
# 분기당_매출_건수       int64
# 주중_매출_금액        int64
# 주말_매출_금액        int64
# 월요일_매출_금액       int64
# 화요일_매출_금액       int64
# 수요일_매출_금액       int64
# 목요일_매출_금액       int64
# 금요일_매출_금액       int64
# 토요일_매출_금액       int64
# 일요일_매출_금액       int64
# 점포수             int64
# 시군구            object
# 연도별분기          object
# dtype: object

# %%
len(result)
# Out:
# 336803

# %%
result.iloc[0,-2]
# Out:
# '강동구'

# %%
result['pri_key'] = 0
for i in range(len(result)):
    result['pri_key'][i] = '%s - %s - %s' %(result.iloc[i,0], result.iloc[i,1], result.iloc[i,-2])
# Out:
# /var/folders/p7/569lvwkj0q98gy0g8l5r64b80000gn/T/ipykernel_26965/3973936628.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['pri_key'][i] = '%s - %s - %s' %(result.iloc[i,0], result.iloc[i,1], result.iloc[i,-2])
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
result = result.set_index('서비스_업종_코드')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/p7/569lvwkj0q98gy0g8l5r64b80000gn/T/ipykernel_26965/3350756155.py in <module>
# ----> 1 result = result.set_index('서비스_업종_코드')
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['서비스_업종_코드'] are in the columns"

# %%
result
# Out:
#        서비스_업종_코드_명   분기당_매출_금액  분기당_매출_건수    주중_매출_금액   주말_매출_금액  월요일_매출_금액  \
# 0             예술학원    20061598        125    20061598          0    7736248
# 1              노래방      510636         21      510636          0          0
# 2           시계및귀금속     5085873         10     1695291    3390582    1695291
# 3           일반교습학원      527027         53      527027          0          0
# 4           스포츠 강습    22390312        168    22390312          0    4812871
# ...            ...         ...        ...         ...        ...        ...
# 336798      패스트푸드점   196562293      16515   141248733   55313560   22743080
# 336799         제과점  1659143544     195540  1105438112  553705432  209899348
# 336800       일식음식점   387388456       5821   264295293  123093163   41619598
# 336801       중식음식점   112368498       4671    72648669   39719829   11901040
# 336802       한식음식점  2907921088      74719  2044033181  863887907  340694030
#
# ...

# %%
result.to_csv('result.csv', mode = 'w')

# %%
result['연도별분기'].unique()
# Out:
# array(['2019-1', '2019-2', '2019-3', '2019-4', '2020-1', '2020-3',
#        '2020-2', '2020-4', '2021-2', '2021-1'], dtype=object)

# %%
gu = list(result.시군구.unique())
gu
# Out:
# ['강동구',
#  '성북구',
#  '관악구',
#  '강남구',
#  '구로구',
#  '강북구',
#  '광진구',
#  '종로구',
#  '금천구',
#  '성동구',
#  '동대문구',
#  '서초구',
#  '용산구',
#  '은평구',
#  '영등포구',
#  '도봉구',
#  '중구',
#  '노원구',
#  '중랑구',
#  '동작구',
#  '송파구',
#  '양천구',
#  '서대문구',
#  '마포구',
#  '강서구']

# %% [markdown]
# # 분기별로 나누기

# %%
nineteen_1 = result['연도별분기']=='2019-1'
nineteen_2 = result['연도별분기']=='2019-1'
nineteen_3 = result['연도별분기']=='2019-1'
nineteen_4 = result['연도별분기']=='2019-1'
twenty_1 = result['연도별분기']== '2020-1'
twenty_2 = result['연도별분기']== '2020-2'
twenty_3 = result['연도별분기']== '2020-3'
twenty_4 = result['연도별분기']== '2020-4'
twenty_one_1 = result['연도별분기']== '2021-1'
twenty_one_2 = result['연도별분기']== '2021-2'

nineteen_1_pd = result[nineteen_1]
nineteen_2_pd = result[nineteen_2]
nineteen_3_pd = result[nineteen_3]
nineteen_4_pd = result[nineteen_4]
twenty_1_pd = result[twenty_1]
twenty_2_pd = result[twenty_2]
twenty_3_pd = result[twenty_3]
twenty_4_pd = result[twenty_4]
twenty_one_1_pd = result[twenty_one_1]
twenty_one_2_pd = result[twenty_one_2]

# %% [markdown]
# # 특정 구 추출

# %%
loc = (result.시군구 == '강남구')

# %%
result_loc=result[loc]

# %%
result_loc
# Out:
#       서비스_업종_코드 서비스_업종_코드_명   분기당_매출_금액  분기당_매출_건수  주중_매출_비율  주말_매출_비율  \
# 4      CS200001      일반교습학원      527027         53       100         0
# 206    CS200030       피부관리실    32583826         50        83        17
# 617    CS200028         미용실   281726589       2663        71        29
# 961    CS200007        치과의원   131678931        480        91         9
# 962    CS200001      일반교습학원  4651539187      14799        62        38
# ...         ...         ...         ...        ...       ...       ...
# 43827  CS100006      패스트푸드점   228705861      15027        73        27
# 43828  CS100005         제과점   160894613      14829        60        40
# 43829  CS100003       일식음식점   179707222       2341        87        13
# 43830  CS100002       중식음식점   121759965       5464        78        22
# 43831  CS100001       한식음식점  1678953641      37514        81        19
#
#        월요일_매출_비율  화요일_매출_비율  수요일_매출_비율  목요일_매출_비율  ...  여성_매출_건수  \
# ...

# %% [markdown]
# 업종이 63개임

# %%
len(result_loc['서비스_업종_코드_명'].unique())
# Out:
# 63

# %%
sang = list(result_loc['서비스_업종_코드_명'].unique()) #업종컬럼을 리스트로받음

# %%
gu = list(result.시군구.unique())
gu
# Out:
# ['강동구',
#  '성북구',
#  '관악구',
#  '강남구',
#  '구로구',
#  '강북구',
#  '광진구',
#  '종로구',
#  '금천구',
#  '성동구',
#  '동대문구',
#  '서초구',
#  '용산구',
#  '은평구',
#  '영등포구',
#  '도봉구',
#  '중구',
#  '노원구',
#  '중랑구',
#  '동작구',
#  '송파구',
#  '양천구',
#  '서대문구',
#  '마포구',
#  '강서구']

# %%
df_gu = pd.DataFrame(gu)
df_gu
# Out:
#        0
# 0    강동구
# 1    성북구
# 2    관악구
# 3    강남구
# 4    구로구
# 5    강북구
# 6    광진구
# 7    종로구
# 8    금천구
# 9    성동구
# 10  동대문구
# 11   서초구
# 12   용산구
# 13   은평구
# 14  영등포구
# 15   도봉구
# 16    중구
# 17   노원구
# 18   중랑구
# 19   동작구
# 20   송파구
# 21   양천구
# 22  서대문구
# 23   마포구
# 24   강서구

# %%
eng_gu = ['gangdong', 'seongbuk', 'gwanak', 'gangnam', 'guro', 'gangbuk', 'gwangjin', 'jongno', 'geumcheon', 'seongdong'
,'dongdaemun' , 'seocho', 'yongsan', 'eunpyeong' , 'yeongdeungpo', 'dobong', 'jung', 'nowon', 'jungnang', 'dongjak', 'songpa', 'yangcheon', 'seodaemun', 'mapo','gangseo'
         
         
         
         ]

# %%
kind = [] #업종별 매출건수 데이터프레임을 담을 리스트 생성
count = 0
list_kind = []
for j in gu:
    loc = (result.시군구 == j)
    result_loc=result[loc]
    for i in sang:
        condition = (result_loc.서비스_업종_코드_명 == i)
        kind_df = pd.DataFrame(result_loc[condition].groupby('연도별분기').sum())
        kind_df = pd.DataFrame(kind_df['분기당_매출_금액'])
        kind.append(kind_df)
        count += 1
        if count == 63:
            list_kind.append(kind)
            kind = []
            count = 0
num = 0
for j in eng_gu:
    
    for k in list_kind:
        result = pd.concat(k,axis = 1)
        result.columns = sang
        result = result.fillna('0')
        result = result.astype(int)
        result = result.transpose()
        result['시군구'] = gu[num]
        result.to_csv(f'{j}.csv')
    num += 1
# result_01=pd.concat(kind,axis=1) #가로로 데이터프레임 합치기
# result_01.columns = sang #데이터프레임 컬럼명 수정

# %%
result.dtypes
# Out:
# 연도별분기
# 2019-1     int64
# 2019-2     int64
# 2019-3     int64
# 2019-4     int64
# 2020-1     int64
# 2020-2     int64
# 2020-3     int64
# 2020-4     int64
# 2021-1     int64
# 2021-2     int64
# 시군구       object
# dtype: object

# %%
df = pd.DataFrame(sang, columns=['sector'])

# %%
df_r = df.set_index("sector")

# %%
df_r
# Out:
# Empty DataFrame
# Columns: []
# Index: [일반교습학원, 피부관리실, 미용실, 치과의원, 네일숍, 자동차수리, 한식음식점, 치킨전문점, 커피-음료, 일반의류, 편의점, 시계및귀금속, 세탁소, 핸드폰, 반찬가게, 중식음식점, 한의원, 예술학원, 슈퍼마켓, 분식전문점, 육류판매, 전자상거래업, 화초, 안경, 일식음식점, 스포츠클럽, 조명용품, 양식음식점, 가전제품, 서적, 호프-간이주점, 제과점, 화장품, 외국어학원, 당구장, 골프연습장, PC방, 의약품, 여관, 일반의원, 컴퓨터및주변장치판매, 철물점, 수산물판매, 의료기기, 가방, 가구, 패스트푸드점, 인테리어, 섬유제품, 노래방, 운동/경기용품, 자전거 및 기타운송장비, 애완동물, 스포츠 강습, 자동차미용, 가전제품수리, 부동산중개업, 문구, 청과상, 미곡판매, 신발, 고시원, 완구]
#
# [63 rows x 0 columns]

# %%
df_r.to_csv("sector.csv",  mode='w')

# %% [markdown]
# # 데이터프레임 병합

# %% [markdown]
# condition으로 업종별 분기데이터 컬럼을 추출 후 다 63개 데이터프레임을 합친다.

# %%
kind = [] #업종별 매출건수 데이터프레임을 담을 리스트 생성
for i in sang:
    condition = (result_loc.서비스_업종_코드_명 == i)
    kind_df = pd.DataFrame(result_loc[condition].groupby('연도별분기').sum())
    kind_df = pd.DataFrame(kind_df['분기당_매출_건수'])
    kind.append(kind_df)

result_inds=pd.concat(kind,axis=1) #가로로 데이터프레임 합치기
result_inds.columns = sang #데이터프레임 컬럼명 수정
            
len(sang)
# Out:
# 63

# %%
result_ind_tran = result_inds.transpose()

# %%
result_ind_tran.to_csv("sales.csv",  mode='w')

# %%
kinds = [] #업종별 데이터프레임을 담을 리스트 생성
for i in sang:
    condition = (result_loc.서비스_업종_코드_명 == i)
    kind_df = pd.DataFrame(result_loc[condition].groupby('연도별분기').sum())
    kind_df = pd.DataFrame(kind_df['분기당_매출_금액'])
    kinds.append(kind_df)

result_ind=pd.concat(kind,axis=1) #가로로 데이터프레임 합치기
result_ind.columns = sang #데이터프레임 컬럼명 수정

# %%
result.columns
# Out:
# Index(['서비스_업종_코드', '서비스_업종_코드_명', '분기당_매출_금액', '분기당_매출_건수', '주중_매출_비율',
#        '주말_매출_비율', '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율',
#        '금요일_매출_비율', '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율',
#        '시간대_06~11_매출_비율', '시간대_11~14_매출_비율', '시간대_14~17_매출_비율',
#        '시간대_17~21_매출_비율', '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율',
#        '연령대_10_매출_비율', '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율',
#        '연령대_50_매출_비율', '연령대_60_이상_매출_비율', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액',
#        '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액',
#        '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
#        '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
#        '주말_매출_건수', '월요일_매출_건수', '화요일_매출_건수', '수요일_매출_건수', '목요일_매출_건수',
# ...

# %%
result_ind
# Out:
#         일반교습학원   피부관리실     미용실    치과의원    네일숍  자동차수리     한식음식점   치킨전문점  \
# 연도별분기
# 2019-1  258002   89860  659339  354934  39582  54563  11860273  640883
# 2019-2  200580   82600  635191  339553  46756  60554  10932380  588976
# 2019-3  272547   92895  667193  362634  43995  56103  12372394  599403
# 2019-4  498786   92948  692517  364874  39142  70341  12734780  617955
# 2020-1  337108   78434  584732  318352  29744  64579  11014869  534184
# 2020-2  384702   89515  632103  342027  31748  80787  10965166  565094
# 2020-3  417622   85068  609618  346010  30859  72572  10595115  478277
# 2020-4  403510   74955  566646  338967  25093  67309   9734834  416759
# 2021-1  323793   95130  570152  333375  23666  65322   9018494  346283
# 2021-2  345036  146716  678354  354140  27602  69729  10586467  399027
#
#            커피-음료     일반의류  ...  스포츠 강습  자동차미용  가전제품수리  부동산중개업       문구  \
# 연도별분기                      ...
# 2019-1  12916696  2400174  ...   33343  45897    6406   98124  1517614
# ...

# %%
result_inds
# Out:
#         일반교습학원   피부관리실     미용실    치과의원    네일숍  자동차수리     한식음식점   치킨전문점  \
# 연도별분기
# 2019-1  258002   89860  659339  354934  39582  54563  11860273  640883
# 2019-2  200580   82600  635191  339553  46756  60554  10932380  588976
# 2019-3  272547   92895  667193  362634  43995  56103  12372394  599403
# 2019-4  498786   92948  692517  364874  39142  70341  12734780  617955
# 2020-1  337108   78434  584732  318352  29744  64579  11014869  534184
# 2020-2  384702   89515  632103  342027  31748  80787  10965166  565094
# 2020-3  417622   85068  609618  346010  30859  72572  10595115  478277
# 2020-4  403510   74955  566646  338967  25093  67309   9734834  416759
# 2021-1  323793   95130  570152  333375  23666  65322   9018494  346283
# 2021-2  345036  146716  678354  354140  27602  69729  10586467  399027
#
#            커피-음료     일반의류  ...  스포츠 강습  자동차미용  가전제품수리  부동산중개업       문구  \
# 연도별분기                      ...
# 2019-1  12916696  2400174  ...   33343  45897    6406   98124  1517614
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt

import platform
print(platform.system()) 
# 플랫폼 확인 # Window 
if platform.system() == 'Windows': 
    matplotlib.rc('font', family='Malgun Gothic')
elif platform.system() == 'Darwin': # Mac 
    matplotlib.rc('font', family='AppleGothic') 
else: #linux
    matplotlib.rc('font', family='NanumGothic') # 그래프에 마이너스 표시가 되도록 변경
    matplotlib.rcParams['axes.unicode_minus'] = False
# Out:
# Darwin

# %%
result_ind.plot(y=sang, logy = True,figsize=(10,6),grid=True, xlabel='분기별',ylabel='지역',marker='o',ms =3)
# Out:
# <AxesSubplot:xlabel='분기별', ylabel='지역'>

# %% [markdown]
# # pc방 데이터 시각화

# %%
result_ind.plot(y=['PC방'], logy = True,figsize=(10,6),grid=True, xlabel='분기별',ylabel='매출',marker='o',ms =3)
plt.legend()
xs = result_ind.index.to_list()
ys = result_ind['PC방'].to_list()
plt.figure(figsize=(10,6))
plt.xlabel('quarter')
plt.ylabel('PC방')
plt.bar(xs,ys,width=0.8, color='grey')
# Out:
# <BarContainer object of 10 artists>
